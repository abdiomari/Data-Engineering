# %%
import requests
import pandas as pd

# %%
url = 'https://newsapi.org/v2/everything?q=apple&from=2026-06-09&to=2026-06-09&sortBy=popularity&apiKey=2bf6f6301f924a82b621b3aec134747f'


res = requests.get(url)
data = res.json()

print(res.status_code)
type(data)
# Out:
# 200
# dict

# %%
print(data)
# Out:
# {'status': 'ok', 'totalResults': 2183, 'articles': [{'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Luke Larsen', 'title': 'MacOS 27 Golden Gate: Top New Features', 'description': "Apple has announced the latest version of macOS. It's all about the reintroduction of Siri, which is now accessible from anywhere on the Mac desktop.", 'url': 'https://www.wired.com/story/macos-27-golden-gate-top-features/', 'urlToImage': 'https://media.wired.com/photos/6a2849c20d6aa02c6a8cdf9e/191:100/w_1280,c_limit/Apple-OS-27-updates-260608.jpg', 'publishedAt': '2026-06-09T17:33:21Z', 'content': 'One of the most interesting new features is Custom Extensions, which lets you create an extension for Safari in natural language. Lastly, the new version of Safari will work the Passwords app to auto… [+2328 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Robert Hart', 'title': 'Apple wants Europe to blink', 'description': "It took a few years, but Apple finally made its AI look useful. Now millions of iPhone users in Europe are being told they won't be getting Siri AI anytime soon, if ever - and Apple wants them to blame the EU. Apple says its new AI-powered Siri will not launc…", 'url': 'https://www.theverge.com/ai-artificial-intelligence/947051/apple-europe-dma-siri-ai', 'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK450_EU_G.jpg?quality=90&strip=all&crop=0%2C9.9676601489831%2C100%2C80.064679702034&w=1200', 'publishedAt': '2026-06-09T17:13:14Z', 'content': '<ul><li></li><li></li><li></li></ul>\r\nApple wants Europe to blink\r\nApple blames DMA for delaying Siri AI in Europe. The EU says nothing is stopping Apple from launching it. \r\nby\r\nRobert HartClose\r\nPo… [+7489 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Stevie Bonifield', 'title': 'The App Store is going to add subscription bundles soon', 'description': "Later this year, you will be able to get bundled subscriptions for iPhone apps, as Apple announced it's expanding App Store bundles so they can include offers from different companies. It's similar to streaming video bundles that have combined offers for Appl…", 'url': 'https://www.theverge.com/tech/947365/apple-subscription-bundles-app-store', 'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/23925966/acastro_STK045_01.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200', 'publishedAt': '2026-06-09T21:30:48Z', 'content': '<ul><li></li><li></li><li></li></ul>\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nby\r\nStevie Bonifiel… [+2188 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'David Pierce', 'title': 'Apple’s best AI idea looks a lot like vibe coding', 'description': "Most of Apple's current AI ideas are roughly the same as everyone else's AI ideas. A chatbot you can ask questions; quick ways to create or summarize text; bizarre, borderline creepy image-generation tools. The company spent most of its WWDC keynote playing c…", 'url': 'https://www.theverge.com/tech/946733/apple-shortcuts-ai-safari-tabs-vibe-code', 'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/AI-Apple-Shortcuts.jpg?quality=90&strip=all&crop=0%2C3.3555449785816%2C100%2C93.288910042837&w=1200', 'publishedAt': '2026-06-09T13:34:48Z', 'content': '<ul><li></li><li></li><li></li></ul>\r\nApples best AI idea looks a lot like vibe coding\r\nSiri AI and Image Playground will get all the hype, but Apple can actually make our lives better in Safari and … [+7449 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'John.Higgins', 'title': 'The three sets of earbuds I reach for', 'description': 'I have been an audio reviewer for 20 years. My time as a freelance headphones panelist at Wirecutter, and the multitude of reviews  ...

# %%
articles = data.get('articles')
print(articles)
# Out:
# [{'source': {'id': 'wired', 'name': 'Wired'}, 'author': 'Luke Larsen', 'title': 'MacOS 27 Golden Gate: Top New Features', 'description': "Apple has announced the latest version of macOS. It's all about the reintroduction of Siri, which is now accessible from anywhere on the Mac desktop.", 'url': 'https://www.wired.com/story/macos-27-golden-gate-top-features/', 'urlToImage': 'https://media.wired.com/photos/6a2849c20d6aa02c6a8cdf9e/191:100/w_1280,c_limit/Apple-OS-27-updates-260608.jpg', 'publishedAt': '2026-06-09T17:33:21Z', 'content': 'One of the most interesting new features is Custom Extensions, which lets you create an extension for Safari in natural language. Lastly, the new version of Safari will work the Passwords app to auto… [+2328 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Robert Hart', 'title': 'Apple wants Europe to blink', 'description': "It took a few years, but Apple finally made its AI look useful. Now millions of iPhone users in Europe are being told they won't be getting Siri AI anytime soon, if ever - and Apple wants them to blame the EU. Apple says its new AI-powered Siri will not launc…", 'url': 'https://www.theverge.com/ai-artificial-intelligence/947051/apple-europe-dma-siri-ai', 'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/STK450_EU_G.jpg?quality=90&strip=all&crop=0%2C9.9676601489831%2C100%2C80.064679702034&w=1200', 'publishedAt': '2026-06-09T17:13:14Z', 'content': '<ul><li></li><li></li><li></li></ul>\r\nApple wants Europe to blink\r\nApple blames DMA for delaying Siri AI in Europe. The EU says nothing is stopping Apple from launching it. \r\nby\r\nRobert HartClose\r\nPo… [+7489 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'Stevie Bonifield', 'title': 'The App Store is going to add subscription bundles soon', 'description': "Later this year, you will be able to get bundled subscriptions for iPhone apps, as Apple announced it's expanding App Store bundles so they can include offers from different companies. It's similar to streaming video bundles that have combined offers for Appl…", 'url': 'https://www.theverge.com/tech/947365/apple-subscription-bundles-app-store', 'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/chorus/uploads/chorus_asset/file/23925966/acastro_STK045_01.jpg?quality=90&strip=all&crop=0%2C10.732984293194%2C100%2C78.534031413613&w=1200', 'publishedAt': '2026-06-09T21:30:48Z', 'content': '<ul><li></li><li></li><li></li></ul>\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nAlong with iOS 27, Apple also announced big changes to the App Store.\r\nby\r\nStevie Bonifiel… [+2188 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'David Pierce', 'title': 'Apple’s best AI idea looks a lot like vibe coding', 'description': "Most of Apple's current AI ideas are roughly the same as everyone else's AI ideas. A chatbot you can ask questions; quick ways to create or summarize text; bizarre, borderline creepy image-generation tools. The company spent most of its WWDC keynote playing c…", 'url': 'https://www.theverge.com/tech/946733/apple-shortcuts-ai-safari-tabs-vibe-code', 'urlToImage': 'https://platform.theverge.com/wp-content/uploads/sites/2/2026/06/AI-Apple-Shortcuts.jpg?quality=90&strip=all&crop=0%2C3.3555449785816%2C100%2C93.288910042837&w=1200', 'publishedAt': '2026-06-09T13:34:48Z', 'content': '<ul><li></li><li></li><li></li></ul>\r\nApples best AI idea looks a lot like vibe coding\r\nSiri AI and Image Playground will get all the hype, but Apple can actually make our lives better in Safari and … [+7449 chars]'}, {'source': {'id': 'the-verge', 'name': 'The Verge'}, 'author': 'John.Higgins', 'title': 'The three sets of earbuds I reach for', 'description': 'I have been an audio reviewer for 20 years. My time as a freelance headphones panelist at Wirecutter, and the multitude of reviews I’ve written for sites like Reviewed, Digital Trend ...

# %%
articles_df = pd.DataFrame(articles)
articles_df.head()
# Out:
#                                      source            author  \
# 0          {'id': 'wired', 'name': 'Wired'}       Luke Larsen
# 1  {'id': 'the-verge', 'name': 'The Verge'}       Robert Hart
# 2  {'id': 'the-verge', 'name': 'The Verge'}  Stevie Bonifield
# 3  {'id': 'the-verge', 'name': 'The Verge'}      David Pierce
# 4  {'id': 'the-verge', 'name': 'The Verge'}      John.Higgins
#
#                                                title  \
# 0             MacOS 27 Golden Gate: Top New Features
# 1                        Apple wants Europe to blink
# 2  The App Store is going to add subscription bun...
# 3  Apple’s best AI idea looks a lot like vibe coding
# 4              The three sets of earbuds I reach for
#
#                                          description  \
# 0  Apple has announced the latest version of macO...
# 1  It took a few years, but Apple finally made it...
# 2  Later this year, you will be able to get bundl...
# 3  Most of Apple's current AI ideas are roughly t...
# 4  I have been an audio reviewer for 20 years. My...
#
#                                                  url  \
# 0  https://www.wired.com/story/macos-27-golden-ga...
# 1  https://www.theverge.com/ai-artificial-intelli...
# 2  https://www.theverge.com/tech/947365/apple-sub...
# 3  https://www.theverge.com/tech/946733/apple-sho...
# 4  https://www.theverge.com/gadgets/947325/three-...
#
#                                           urlToImage           publishedAt  \
# 0  https://media.wired.com/photos/6a2849c20d6aa02...  2026-06-09T17:33:21Z
# 1  https://platform.theverge.com/wp-content/uploa...  2026-06-09T17:13:14Z
# 2  https://platform.theverge.com/wp-content/uploa...  2026-06-09T21:30:48Z
# 3  https://platform.theverge.com/wp-content/uploa...  2026-06-09T13:34:48Z
# 4  https://platform.theverge.com/wp-content/uploa...  2026-06-09T22:21:07Z
#
#                                              content
# 0  One of the most interesting new features is Cu...
# 1  <ul><li></li><li></li><li></li></ul>\r\nApple ...
# 2  <ul><li></li><li></li><li></li></ul>\r\nAlong ...
# 3  <ul><li></li><li></li><li></li></ul>\r\nApples...
# 4  <ul><li></li><li></li><li></li></ul>\r\nEarbud...

# %%
from sqlalchemy import create_engine, text

# %%
DATABASE_NAME = 'postgres'
USER = 'postgres'
PORT = 5432
DATABASE_PASSWORD = '1234'
HOST = '127.0.0.1'

engine = create_engine(f'postgresql+psycopg2://{USER}:{DATABASE_PASSWORD}@{HOST}:{PORT}/{DATABASE_NAME}')

# %%
articles_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   source       97 non-null     object
#  1   author       95 non-null     str
#  2   title        97 non-null     str
#  3   description  96 non-null     str
#  4   url          97 non-null     str
#  5   urlToImage   94 non-null     str
#  6   publishedAt  97 non-null     str
#  7   content      97 non-null     str
# dtypes: object(1), str(7)
# memory usage: 6.2+ KB

# %%
articles_df.drop(columns=['source', 'urlToImage'], inplace=True)

# %%
articles_df.to_sql('articles', engine, if_exists='append', index=False)
# Out:
# 97
