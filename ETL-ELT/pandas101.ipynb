# %%
import pandas as pd

# %% [markdown]
# - Read from a csv file and convert to a dataframe

# %%
csv_df = pd.read_csv('random.csv')

# %% [markdown]
# - Show the first 5 items in a dataframe

# %%
csv_df.head()
# Out:
#    id  first_name last_name                        email       gender  \
# 0   1  Bernardine   Sappell        bsappell0@cornell.edu       Female
# 1   2       Lilah    Jewitt           ljewitt1@prweb.com       Female
# 2   3       Reena    Leward         rleward2@webnode.com       Female
# 3   4    Corrinne     Betty  cbetty3@creativecommons.org       Female
# 4   5      Hashim    Boagey          hboagey4@discuz.net  Genderfluid
#
#         ip_address
# 0     8.163.204.26
# 1   244.233.34.193
# 2   154.35.205.179
# 3  176.111.219.240
# 4   219.92.255.147

# %% [markdown]
# - Read from a json file and use tail to show last 5 items

# %%
json_df = pd.read_json('users.json')
json_df.tail()
# Out:
#        id  first_name   last_name                          email      gender  \
# 995   996       Carey     Larwell           clarwellrn@jigsy.com        Male
# 996   997  Huntington      Medler         hmedlerro@google.co.jp        Male
# 997   998       Marjy  Greengrass  mgreengrassrp@ycombinator.com      Female
# 998   999    Filberte      Picard           fpicardrq@dion.ne.jp        Male
# 999  1000       Kiley      Jerram         kjerramrr@springer.com  Polygender
#
#          ip_address
# 995  132.86.101.110
# 996  249.246.100.13
# 997  221.252.246.19
# 998   125.139.245.2
# 999  111.210.31.247

# %% [markdown]
# - To list the columns on a dataframe

# %%
csv_df.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address'], dtype='object')

# %% [markdown]
# - show the number of rows and columns

# %%
csv_df.shape
# Out:
# (1000, 6)

# %% [markdown]
# - shows summary statistocs for numerical columns

# %%
csv_df.describe()
# Out:
#                 id
# count  1000.000000
# mean    500.500000
# std     288.819436
# min       1.000000
# 25%     250.750000
# 50%     500.500000
# 75%     750.250000
# max    1000.000000

# %%
csv_df.describe
# Out:
# <bound method NDFrame.describe of        id  first_name last_name                        email       gender  \
# 0       1  Bernardine   Sappell        bsappell0@cornell.edu       Female
# 1       2       Lilah    Jewitt           ljewitt1@prweb.com       Female
# 2       3       Reena    Leward         rleward2@webnode.com       Female
# 3       4    Corrinne     Betty  cbetty3@creativecommons.org       Female
# 4       5      Hashim    Boagey          hboagey4@discuz.net  Genderfluid
# ..    ...         ...       ...                          ...          ...
# 995   996      Jasper   Purveys            jpurveysrn@w3.org         Male
# 996   997      Aileen     Bibby          abibbyro@amazon.com   Polygender
# 997   998   Alexander   Tomovic        atomovicrp@meetup.com         Male
# 998   999    Rayshell     Ribou         rribourq@youtube.com   Non-binary
# 999  1000      Kelley   Giraldo        kgiraldorr@boston.com       Female
#
#           ip_address           full_name
# ...

# %%
csv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   ip_address  1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
csv_df[['first_name', 'last_name']]
# Out:
#      first_name last_name
# 0    Bernardine   Sappell
# 1         Lilah    Jewitt
# 2         Reena    Leward
# 3      Corrinne     Betty
# 4        Hashim    Boagey
# ..          ...       ...
# 995      Jasper   Purveys
# 996      Aileen     Bibby
# 997   Alexander   Tomovic
# 998    Rayshell     Ribou
# 999      Kelley   Giraldo
#
# [1000 rows x 2 columns]

# %%
csv_df['full_name'] = csv_df['first_name'] + ' ' +  csv_df['last_name'] 
csv_df.tail()
# Out:
#        id first_name last_name                  email      gender  \
# 995   996     Jasper   Purveys      jpurveysrn@w3.org        Male
# 996   997     Aileen     Bibby    abibbyro@amazon.com  Polygender
# 997   998  Alexander   Tomovic  atomovicrp@meetup.com        Male
# 998   999   Rayshell     Ribou   rribourq@youtube.com  Non-binary
# 999  1000     Kelley   Giraldo  kgiraldorr@boston.com      Female
#
#           ip_address          full_name
# 995   255.25.219.102     Jasper Purveys
# 996  138.203.215.143       Aileen Bibby
# 997    241.47.237.85  Alexander Tomovic
# 998   185.101.16.170     Rayshell Ribou
# 999    57.225.41.213     Kelley Giraldo
